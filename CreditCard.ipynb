# %%
import pandas as pd 

creditcard_df=pd.read_csv('creditcard.csv')

creditcard_df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
creditcard_df.shape

creditcard_df.isnull().sum()

# creditcard_df.columns
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
y=creditcard_df['Class']

creditcard_df.drop(columns='Class', inplace=True)

# %%
# sci-kit learn

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(creditcard_df,y,test_size=0.2,random_state=42)

X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223361  143352.0  1.955041 -0.380783 -0.315013  0.330155 -0.509374 -0.086197
# 165061  117173.0 -0.400975 -0.626943  1.555339 -2.017772 -0.107769  0.168310
# 238186  149565.0  0.072509  0.820566 -0.561351 -0.709897  1.080399 -0.359429
# 150562   93670.0 -0.535045  1.014587  1.750679  2.769390  0.500089  1.002270
# 138452   82655.0 -4.026938  1.897371 -0.429786 -0.029571 -0.855751 -0.480406
# ...          ...       ...       ...       ...       ...       ...       ...
# 119879   75618.0  1.173488  0.100792  0.490512  0.461596 -0.296377 -0.213165
# 259178  159000.0 -0.775981  0.144023 -1.142399 -1.241113  1.940358  3.912076
# 131932   79795.0 -0.146609  0.992946  1.524591  0.485774  0.349308 -0.815198
# 146867   87931.0 -2.948638  2.354849 -2.521201 -3.798905  1.866302  2.727695
# 121958   76381.0  1.233174 -0.784851  0.386784 -0.698559 -1.034018 -0.637028
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression()

logreg.fit(X_train,y_train) # Train the model

y_pred=logreg.predict(X_test) # Predicting the test data

y_pred
# Out:
# D:\New folder\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score,roc_curve,roc_auc_score

confusion_matrix(y_test,y_pred)
print('Precision-Score',precision_score(y_test,y_pred))
print('Recall Score',recall_score(y_test,y_pred))
print('F1-Score',f1_score(y_test,y_pred))
# Out:
# Precision-Score 0.8253968253968254
# Recall Score 0.5306122448979592
# F1-Score 0.6459627329192548

# %%
logreg.predict_proba(X_test)[::,1]
# Out:
# array([9.99998090e-01, 5.43177123e-04, 1.54873755e-03, ...,
#        4.23582355e-03, 1.82364752e-04, 1.96100997e-04])

# %%
import matplotlib.pyplot as plt

logregpred_probab=logreg.predict_proba(X_test)[::,1]

fpr,tpr,thresholds=roc_curve(y_test,logregpred_probab)


auc = roc_auc_score(y_test, logregpred_probab)

plt.plot(fpr,tpr,label='auc='+str(auc))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUC-ROC Curve')

plt.legend(loc=8)

# %%
fpr,tpr,thresholds
# Out:
# (array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.75858188e-05, 1.75858188e-05, 7.03432752e-05,
#         7.03432752e-05, 1.05514913e-04, 1.05514913e-04, 1.23100732e-04,
#         1.23100732e-04, 1.40686550e-04, 1.40686550e-04, 1.58272369e-04,
#         1.58272369e-04, 1.75858188e-04, 1.75858188e-04, 1.93444007e-04,
#         1.93444007e-04, 2.11029826e-04, 2.11029826e-04, 2.46201463e-04,
#         2.46201463e-04, 3.16544738e-04, 3.16544738e-04, 3.69302195e-04,
#         3.69302195e-04, 3.86888014e-04, 3.86888014e-04, 4.57231289e-04,
#         4.57231289e-04, 4.74817107e-04, 4.74817107e-04, 5.09988745e-04,
#         5.09988745e-04, 5.45160383e-04, 5.45160383e-04, 5.62746201e-04,
#         5.62746201e-04, 5.80332020e-04, 5.80332020e-04, 7.38604389e-04,
#         7.38604389e-04, 8.96876759e-04, 8.96876759e-04, 1.44203714e-03,
#         1.44203714e-03, 1.72341024e-03, 1.72341024e-03, 1.74099606e-03,
# ...

# %%
auc
# Out:
# 0.952459430592721
